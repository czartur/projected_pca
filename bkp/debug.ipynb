# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# characteristic functions

def g1(x):
    return x

def g2(x):
     return np.power(x,2) - 1

def g3(x):
    return np.power(x,3) - 2*x

def g_mix(x):
    return np.power(x,3)-5

# %%
from simulation import gen_simulated_data
 
T = 50
p = 200

functions = [[g1],
             [g2],
             [g3]]

# functions = [[g1, g2]]

X, Y, F, Lambda, Gamma = gen_simulated_data(p, T, functions)

# %%
from PPCA import ProjectedPCA

ppca = ProjectedPCA('spl', K = None).fit(X,Y)

ppca.plot_K()
ppca.plot_factor(0,0)
ppca.plot_Y(0)
print("F error:", np.linalg.norm(F - ppca.F_hat))
# Out:
# F error: 14.156336306862316
